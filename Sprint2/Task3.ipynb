// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидуальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// ----
//
// ### Вариант задания №1

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// Создать базовый класс Person в C#, который будет представлять информацию о
// человеке. На основе этого класса разработать 2-3 производных класса,
// демонстрирующих принципы наследования и полиморфизма. В каждом из классов
// должны быть реализованы новые атрибуты и методы, а также переопределены
// некоторые методы базового класса для демонстрации полиморфизма.
//
// Требования к базовому классу Person:
// • Атрибуты: Имя (Name), Возраст (Age), Пол (Gender).
// • Методы:
// o GetInfo(): метод для получения информации о человеке в виде строки.
// o SayHello(): метод для вывода приветствия от человека.
//
// Требования к производным классам:
// 1. Студент (Student): Должен содержать дополнительные атрибуты, такие как
// Университет (University) и Курс (Course). Метод SayHello() должен быть
// переопределен для добавления информации о курсе при приветствии.
// 2. Работник (Employee): Должен содержать дополнительные атрибуты, такие
// как Компания (Company) и Зарплата (Salary). Метод GetInfo() должен быть
// переопределен для включения информации о компании и зарплате.
// 3. Преподаватель (Teacher) (если требуется третий класс): Должен содержать
// дополнительные атрибуты, такие как Предмет (Subject) и Стаж работы
// (Experience). Метод SayHello() должен быть переопределен для добавления
// информации о преподаваемом предмете при приветствии.
//
//
// #### Дополнительное задание
// Добавьте к сущестующим классам (базовыму и производным 3-4 атрибута и метода) и реализуйте простое, сложное и множественное наследование

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
public interface IPerson {
    string Name{get;set;}
    int Age{get;set;}
    string Gender{get;set;}
}
public interface IContactable
{
    string Email { get; set; }
    string PhoneNumber { get; set; }
    void SendMessage(string message);
}

public class Person : IPerson, IContactable
{
    public string Name { get; set; }
    public int Age { get; set; }
    private string _gender;
    private static readonly string[] Genders = {"Женский", "женский", "Мужской", "мужской","ж","м","Ж","М"};
    //выше константа для гендера
    public string Gender
    {   get { return _gender; }
        set { if (Genders.Contains(value))
            {_gender = value;}
            else{throw new ArgumentException("Недопустимое значение пола");}}}

    public string Email { get; set; }
    public string PhoneNumber { get; set; }
    public void SendMessage(string message){
        Console.WriteLine($"{Name} отправяляет сообщение {message}");
    }
    public Person(string name, int Age, string gender, string Email, string PhoneNumber)
    { Name = name; this.Age = Age; Gender = gender; this.Email=Email; this.PhoneNumber=PhoneNumber;// используется паблик переменная, а не приват
    }
    public virtual string GetInfo()
    { return($"{Name}, {Age}, {Gender}");
    }
      public virtual void SayHello()
    {
        Console.WriteLine($"Привет! Меня зовут {Name}. Мой возраст {Age}. Мой пол {Gender}");
        }
    public void CheckAge(){
        
        if (Age>=0 && Age<=17) {
            Console.WriteLine($"Человек с именем {Name} несовершеннолетний(яя), так как ему(ей) {Age} лет(годов)");
        }
        else if (Age>=18 && Age<=44)
        {
             Console.WriteLine($"Человек с именем {Name} совершеннолетний(яя) и является молодым(ой), так как ему(ей) {Age} лет(годов)");
        }
        else if (Age>=44 && Age<=60)
        {
             Console.WriteLine($"Человек с именем {Name} среднего возраста, так как ему(ей) {Age} лет(годов)");
        }
        else if (Age>=60 && Age<=120)
        {
             Console.WriteLine($"{Name} является пожилым, так как ему(ей) {Age} лет(годов)");
        }
        else{
            throw new ArgumentException("Недопустимое значение возраста");
        }}}
class Student : Person
 { 
    public string University{get;set;}
    private int _course;
    public int Course {
            get { return _course; }
            set{
                if ((value>0)&&(value<8)){
                    _course = value;
                }
                else{throw new ArgumentException("Ошибка. Проверьте цифру курса");}
            }}
    protected double[] Grades {get;set;}
    public string studySuject {get;set;}
    public int Year {get;set;}
    public static int countStudent{get; private set;}=0; 

    public Student(string name, int Age, string gender, string university, int course,string Email,string PhoneNumber, string studySuject): base(name, Age, gender,Email,PhoneNumber)
    {University=university;
        Course=course; this.studySuject=studySuject;
        countStudent++;
    }
    public void SetGPA(double[] grades)
    {
        if (grades == null || grades.Length == 0)
        {
            throw new ArgumentException("Массив оценок не может быть null или пустым");
        }
        Grades = grades;
    }
     public override string GetInfo()
    {
        return (base.GetInfo()+$", университет: {University}, курс {Course}, предмет {studySuject},  оценки: {string.Join(", ", Grades)}, средняя оценка: {Math.Round(Grades.Average(),2)}");//- вызов базового метода
        //return($"{University}, {Course}");
    }
    
     public new void SayHello()
    {
        Console.WriteLine($"Привет! Меня зовут {Name}. Мой возраст {Age}. Мой пол {Gender}. Я учусь в \"{University}\" на {Course} курсе.");
         Console.WriteLine($"По номеру я: {countStudent}-ый(ая) студент(ка)");
         
    }   
}
class Employee: Person{
 public string Company{get;set;}
    public double Salary {get;set;}
     public string Departament{get;set;}
public int startYear {get;set;}
public int endYear{get;set;}

    public static int countEmployee{get; private set;}=0; 
    public Employee(string name, int Age, string gender, string company, string Departament, double salary,string Email,string PhoneNumber): base(name, Age, gender, Email, PhoneNumber)
    {
        this.Departament=Departament; Company=company; Salary=salary; countEmployee++;
    }

     public override string GetInfo()
    {  return (base.GetInfo()+$"{Company},{Salary}");
    }
    
    public new void SayHello()
    {
        Console.WriteLine($"Привет! Меня зовут {Name}. Мой возраст {Age}. Я работаю в компании \"{Company}\", в отделении {Departament} и моя зарплата составляет {Salary} рубля(ей).");
       
    }
public void EXp(int startYear, int endYear){
    int exp = endYear-startYear;
   Console.WriteLine($"Стаж работы: {exp}");
}}
 public interface ITeacher
{
    string Subject { get; set; }
    double Experience { get; set; }
    
    void TeachLesson();
    void AssignHomework();
}
class Teacher: Employee, ITeacher {
public string Subject{get;set;}
public double Experience {get;set;}
public static int countTeacher{get; private set;}=0; 
public Teacher(string name, int Age, string gender, string company, string Departament, double salary,string subject,double experience,string Email,string PhoneNumber): base(name, Age, gender,company,Departament,salary,Email, PhoneNumber)
    {
        Subject=subject;
        Experience=experience;
        countTeacher++;
    }
public override string GetInfo(){return (base.GetInfo()+$"{Subject},{Experience}");
    }

public new void SayHello(){
    Console.WriteLine($"Привет! Меня зовут {Name}. Мой возраст {Age}. Я работаю преподавателем в \"{Company}\", на каведре {Departament} и моя зарплата составляет {Salary} рубля(ей).");
    Console.WriteLine($"Я преподаю учебный предмет \"{Subject}\" уже в течение {Experience} лет(года)");
   }
public void TeachLesson()
    {
        Console.WriteLine($"Преподаватель {Name} проводит урок по предмету {Subject}");
    }
public void AssignHomework()
    {
        Console.WriteLine($"Преподаватель {Name} назначает домашнее задание по предмету {Subject}");
    }
    }

Person Guy = new Person ("Миша",19,"м","misha@example.com","89434569423");
Guy.SendMessage("ПРИВЕТ"); Guy.GetInfo(); Guy.SayHello(); Guy.CheckAge();
Student Bread = new Student("Гриша",22,"Мужской","ТИУ",3,"grisha@mail.com","89459003355","Математика");
double[] Gradess = {3.0,4.9,1.2,4.5,3.8,5.0};
Bread.SetGPA(Gradess); Bread.GetInfo(); Bread.SayHello();
Employee Biznes = new Employee("Екатерина",67,"Ж", "СтройДвор","IT",50000.3,"eaterina@mail.com","839483984");
Biznes.GetInfo();Biznes.SayHello();Biznes.EXp(2001,2023);
Teacher Roman = new Teacher("Ангелина",34,"ж","ТИУ","Математические науки",23444.2,"Высшая математика",3.5,"gelya@mail.com","847389574");
Roman.GetInfo();Roman.SayHello();Roman.TeachLesson();Roman.AssignHomework();
// Out:
// Миша отправяляет сообщение ПРИВЕТ
// Привет! Меня зовут Миша. Мой возраст 19. Мой пол м
// Человек с именем Миша совершеннолетний(яя) и является молодым(ой), так как ему(ей) 19 лет(годов)
// Привет! Меня зовут Гриша. Мой возраст 22. Мой пол Мужской. Я учусь в "ТИУ" на 3 курсе.
// По номеру я: 1-ый(ая) студент(ка)
// Привет! Меня зовут Екатерина. Мой возраст 67. Я работаю в компании "СтройДвор", в отделении IT и моя зарплата составляет 50000.3 рубля(ей).
// Стаж работы: 22
// Привет! Меня зовут Ангелина. Мой возраст 34. Я работаю преподавателем в "ТИУ", на каведре Математические науки и моя зарплата составляет 23444.2 рубля(ей).
// Я преподаю учебный предмет "Высшая математика" уже в течение 3.5 лет(года)
// Преподаватель Ангелина проводит урок по предмету Высшая математика
// Преподаватель Ангелина назначает домашнее задание по предмету Высшая математика
